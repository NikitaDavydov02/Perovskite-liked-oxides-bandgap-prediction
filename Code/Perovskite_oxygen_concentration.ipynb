# %%
# !pip install pymatgen
# !pip install mp_api
from pymatgen.core.composition import Composition
from pymatgen.core.periodic_table import Element
from pymatgen.core.structure import Structure
import pandas as pd
import numpy as np
import plotly as pt
import seaborn as sns
import requests
import json
import os
import plotly.express as px
# Out:
# Collecting pymatgen
#   Downloading pymatgen-2025.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting bibtexparser>=1.4.0 (from pymatgen)
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (1.5.2)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (3.10.0)
# Collecting monty>=2025.1.9 (from pymatgen)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (3.5)
# Requirement already satisfied: numpy<3,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (2.0.2)
# Requirement already satisfied: orjson<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (3.11.3)
# Collecting palettable>=3.3.3 (from pymatgen)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (5.24.1)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (2.32.4)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen)
#   Downloading ruamel.yaml-0.18.15-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (1.16.2)
# Collecting spglib>=2.5 (from pymatgen)
#   Downloading spglib-2.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (1.13.3)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from pymatgen) (4.67.1)
# Collecting uncertainties>=3.1.4 (from pymatgen)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from bibtexparser>=1.4.0->pymatgen) (3.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->pymatgen) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->pymatgen) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->pymatgen) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->pymatgen) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->pymatgen) (2025.10.5)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen)
#   Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from spglib>=2.5->pymatgen) (4.15.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->pymatgen) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8->pymatgen) (1.17.0)
# Downloading pymatgen-2025.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 54.2 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.5 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 22.3 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.15-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 9.7 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 46.8 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 4.8 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (753 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.1/753.1 kB 45.0 MB/s eta 0:00:00
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=d922db20e72ba882773281aa07ae034701eca43878b5410d81d8f158a86dd2a5
#   Stored in directory: /root/.cache/pip/wheels/1f/7d/e9/1ff2509f13767a55df1279744adfb757f4ab94b2cbe761f56a
# Successfully built bibtexparser
# Installing collected packages: uncertainties, spglib, ruamel.yaml.clib, palettable, bibtexparser, ruamel.yaml, monty, pymatgen
# Successfully installed bibtexparser-1.4.3 monty-2025.3.3 palettable-3.3.3 pymatgen-2025.10.7 ruamel.yaml-0.18.15 ruamel.yaml.clib-0.2.14 spglib-2.6.0 uncertainties-3.2.3
# Collecting mp_api
#   Downloading mp_api-0.45.12-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from mp_api) (1.1.2)
# Requirement already satisfied: pymatgen!=2024.2.20,>=2022.3.7 in /usr/local/lib/python3.12/dist-packages (from mp_api) (2025.10.7)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.12/dist-packages (from mp_api) (4.15.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from mp_api) (2.32.4)
# Requirement already satisfied: monty>=2024.12.10 in /usr/local/lib/python3.12/dist-packages (from mp_api) (2025.3.3)
# Collecting emmet-core>=0.84.6rc0 (from mp_api)
#   Downloading emmet_core-0.86.0rc0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.12/dist-packages (from mp_api) (7.3.1)
# Collecting boto3 (from mp_api)
#   Downloading boto3-1.40.55-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from emmet-core>=0.84.6rc0->mp_api) (2.11.10)
# Requirement already satisfied: pydantic-settings>=2.0 in /usr/local/lib/python3.12/dist-packages (from emmet-core>=0.84.6rc0->mp_api) (2.11.0)
# Collecting pymatgen-io-validation>=0.1.1 (from emmet-core>=0.84.6rc0->mp_api)
#   Downloading pymatgen_io_validation-0.1.2-py3-none-any.whl.metadata (15 kB)
# Collecting pybtex~=0.24 (from emmet-core>=0.84.6rc0->mp_api)
#   Downloading pybtex-0.25.1-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting blake3 (from emmet-core>=0.84.6rc0->mp_api)
#   Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.12/dist-packages (from monty>=2024.12.10->mp_api) (0.18.15)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from monty>=2024.12.10->mp_api) (2.0.2)
# Requirement already satisfied: bibtexparser>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.4.3)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.5.2)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (3.10.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (3.5)
# Requirement already satisfied: orjson<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (3.11.3)
# Requirement already satisfied: palettable>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (3.3.3)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (5.24.1)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.16.2)
# Requirement already satisfied: spglib>=2.5 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (2.6.0)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.13.3)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pymatgen!=2024.2.20,>=2022.3.7->mp_api) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->mp_api) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->mp_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->mp_api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->mp_api) (2025.10.5)
# Collecting botocore<1.41.0,>=1.40.55 (from boto3->mp_api)
#   Downloading botocore-1.40.55-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->mp_api)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3->mp_api)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open->mp_api) (1.17.3)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from bibtexparser>=1.4.0->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (3.2.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.55->boto3->mp_api) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (11.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.0.0->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (8.5.0)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.12/dist-packages (from pybtex~=0.24->emmet-core>=0.84.6rc0->mp_api) (6.0.3)
# Collecting latexcodec>=1.0.4 (from pybtex~=0.24->emmet-core>=0.84.6rc0->mp_api)
#   Downloading latexcodec-3.0.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->emmet-core>=0.84.6rc0->mp_api) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->emmet-core>=0.84.6rc0->mp_api) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->emmet-core>=0.84.6rc0->mp_api) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0->emmet-core>=0.84.6rc0->mp_api) (1.1.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml->monty>=2024.12.10->mp_api) (0.2.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->pymatgen!=2024.2.20,>=2022.3.7->mp_api) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.55->boto3->mp_api) (1.17.0)
# Downloading mp_api-0.45.12-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.8 MB/s eta 0:00:00
# Downloading emmet_core-0.86.0rc0-py3-none-any.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 13.4 MB/s eta 0:00:00
# Downloading boto3-1.40.55-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 11.5 MB/s eta 0:00:00
# Downloading botocore-1.40.55-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 70.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading pybtex-0.25.1-py2.py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 8.0 MB/s eta 0:00:00
# Downloading pymatgen_io_validation-0.1.2-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 3.4 MB/s eta 0:00:00
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 5.0 MB/s eta 0:00:00
# Downloading blake3-1.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 15.8 MB/s eta 0:00:00
# Downloading latexcodec-3.0.1-py3-none-any.whl (18 kB)
# Installing collected packages: latexcodec, jmespath, blake3, pybtex, botocore, s3transfer, pymatgen-io-validation, boto3, emmet-core, mp_api
# Successfully installed blake3-1.0.8 boto3-1.40.55 botocore-1.40.55 emmet-core-0.86.0rc0 jmespath-1.0.1 latexcodec-3.0.1 mp_api-0.45.12 pybtex-0.25.1 pymatgen-io-validation-0.1.2 s3transfer-0.14.0

# %%
df = pd.read_excel("/content/drive/MyDrive/University/Artificial intelligence in chemistry/Perovskite project/Perovskite-liked-oxides-bandgap-prediction/Data/Perovskite dataset.xlsx",sheet_name='Export')

# %%
df
# Out:
#        Perovskite      Hill formula Interlayer space composition Dopant  \
# 0        K4Nb6O17        K4 Nb6 O17                          NaN    NaN
# 1        KLaNb2O7       K La Nb2 O7                          NaN    NaN
# 2       RbLaNb2O7      La Nb2 O7 Rb                          NaN    NaN
# 3       CsLaNb2O7      Cs La Nb2 O7                          NaN    NaN
# 4      KCa2Nb3O10     Ca2 K Nb3 O10                          NaN    NaN
# ..            ...               ...                          ...    ...
# 518    KCa2Nb3O10     Ca2 K Nb3 O10                          NaN    NaN
# 519  KCa2Nb2TaO10  Ca2 K Nb2 O10 Ta                          NaN    NaN
# 520  KCa2NbTa2O10  Ca2 K Nb O10 Ta2                          NaN    NaN
# 521    KCa2Ta3O10     Ca2 K O10 Ta3                          NaN    NaN
# 522    KCa2Ta3O10     Ca2 K O10 Ta3                          NaN    NaN
#
#      Dopant, wt%  Bandgap, eV                 DOI Materials Project ID  \
# 0            NaN         3.50  10.1007/BF00765319            mp-560692
# 1            NaN         3.20  10.1007/BF00765319           mp-1223501
# 2            NaN         3.35  10.1007/BF00765319            mp-553965
# 3            NaN         3.30  10.1007/BF00765319            mp-553248
# 4            NaN         3.35  10.1007/BF00765319            mp-557195
# ..           ...          ...                 ...                  ...
# 518          NaN         3.50                 NaN                  NaN
# 519          NaN         3.60                 NaN                  NaN
# 520          NaN         3.80                 NaN                  NaN
# 521          NaN         4.20                 NaN                  NaN
# 522          NaN         4.20                 NaN                  NaN
#
#       COD_ID Springer_ID  ...  MagpieData minimum Electronegativity  \
# 0    1001842         NaN  ...                                  0.82
# 1    1545643         NaN  ...                                  0.82
# 2         -1         NaN  ...                                  0.82
# 3    2004917         NaN  ...                                  0.79
# 4    1521061         NaN  ...                                  0.82
# ..       ...         ...  ...                                   ...
# 518      NaN         NaN  ...                                   NaN
# 519      NaN         NaN  ...                                   NaN
# 520      NaN         NaN  ...                                   NaN
# 521      NaN         NaN  ...                                   NaN
# 522      NaN         NaN  ...                                   NaN
#
#      MagpieData maximum Electronegativity  MagpieData range Electronegativity  \
# 0                                    3.44                                2.62
# 1                                    3.44                                2.62
# 2                                    3.44                                2.62
# 3                                    3.44                                2.65
# 4                                    3.44                                2.62
# ..                                    ...                                 ...
# 518                                   NaN                                 NaN
# 519                                   NaN                                 NaN
# 520                                   NaN                                 NaN
# 521                                   NaN                                 NaN
# 522                                   NaN                                 NaN
#
#      MagpieData mean Electronegativity Average Pauling electronegativity  \
# 0                             2.642963                          2.642963
# 1                             2.654545                          2.654545
# 2                             2.654545                          2.654545
# 3                             2.651818                          2.651818
# 4                             2.626250                          2.626250
# ..                                 ...                               ...
# 518                                NaN                               NaN
# 519                                NaN                               NaN
# 520                                NaN                               NaN
# 521                                NaN                               NaN
# 522                                NaN                               NaN
#
#     Average Mulliken electronegativity MP_packing_fraction  \
# 0                             5.958736            0.482644
# 1                             5.994691            0.484504
# 2                             5.986551            0.507344
# 3                             5.973028            0.524329
# 4                             5.966810            0.505552
# ..                                 ...                 ...
# 518                                NaN                 NaN
# 519                                NaN                 NaN
# 520                                NaN                 NaN
# 521                                NaN                 NaN
# 522                                NaN                 NaN
#
#     COD_packing_fraction Springer_packing_fraction  Unnamed: 55
# 0               0.507705                       NaN          NaN
# 1                    NaN                       NaN          NaN
# 2                    NaN                       NaN          NaN
# 3               0.552752                       NaN          NaN
# 4               0.000000                       NaN          NaN
# ..                   ...                       ...          ...
# 518                  NaN                       NaN          NaN
# 519                  NaN                       NaN          NaN
# 520                  NaN                       NaN          NaN
# 521                  NaN                       NaN          NaN
# 522                  NaN                       NaN          NaN
#
# [523 rows x 56 columns]

# %%
import re

def count_oxigen(formula):
  #match = re.search(r'O(\d+)', hill_formula)
  #if match:
  #  number = int(match.group(1))
  #  print(number)
  #  return number
  #else:
  #  print("No match found")
  if formula is None:
    return 0
  print(formula)
  comp = Composition(formula)

  # Get number of oxygen atoms
  oxygen_count = comp.get_el_amt_dict().get("O", 0)
  print(oxygen_count)
  return oxygen_count

# %%
df['Oxygen_count']=df['Hill formula'].apply(count_oxigen)
# Out:
# K4 Nb6 O17
# 17.0
# K La Nb2 O7
# 7.0
# La Nb2 O7 Rb
# 7.0
# Cs La Nb2 O7
# 7.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 Nb3 O10 Rb
# 10.0
# Ca2 Cs Nb3 O10
# 10.0
# K Nb3 O10 Sr2
# 10.0
# Ca2 K Na Nb4 O13
# 13.0
# O2 Ti
# 2.0
# La O7 Rb Ta2
# 7.0
# O7 Pr Rb Ta2
# 7.0
# Nd O7 Rb Ta2
# 7.0
# O7 Rb Sm Ta2
# 7.0
# Ca O6 Ta2
# 6.0
# O6 Sr Ta2
# 6.0
# Ba O6 Ta2
# 6.0
# Bi2 Ca O9 Ta2
# 9.0
# Bi2 O9 Sr Ta2
# 9.0
# Ba Bi2 O9 Ta2
# 9.0
# Bi2 Ca Nb2 O9
# 9.0
# Bi2 Nb2 O9 Sr
# 9.0
# Ba Bi2 Nb2 O9
# 9.0
# Bi2 Nb1.8 O9 Pb W0.2
# 9.0
# Bi2 Nb1.85 O9 Pb W0.15
# 9.0
# Bi2 Nb1.9 O9 Pb W0.1
# 9.0
# Bi2 Nb2 O9 Pb
# 9.0
# Bi2 Nb1.9 O9 Pb Ti0.1
# 9.0
# O2 Ti
# 2.0
# La O7 Rb Ta2
# 7.0
# O7 Pr Rb Ta2
# 7.0
# Nd O7 Rb Ta2
# 7.0
# O7 Rb Sm Ta2
# 7.0
# Bi4 Ca O15 Ti4
# 15.0
# Bi4 O15 Pb Ti4
# 15.0
# Bi2 Ca Nb2 O9
# 9.0
# Bi2 Nb2 O9 Pb
# 9.0
# Ca1.5 K0.5 La0.5 Nb3 O10
# 10.0
# Ca0.75 K0.5 La0.5 Nb3 O10 Pb0.75
# 10.0
# Bi0.25 Ca0.75 K0.5 La0.25 Nb3 O10 Pb0.75
# 10.0
# O7 Sr3 Ti2
# 7.0
# O3 Pb Ti
# 3.0
# Nb4 O15 Sr5
# 15.0
# Ba5 Nb4 O15
# 15.0
# Ca La4 O15 Ti4
# 15.0
# Ba La4 O15 Ti4
# 15.0
# La4 O12 Ti3
# 12.0
# Ca La4 O15 Ti4
# 15.0
# La4 O15 Sr Ti4
# 15.0
# Ba La4 O15 Ti4
# 15.0
# Ba3 La Nb3 O12
# 12.0
# Nb4 O15 Sr5
# 15.0
# Ba5 Nb4 O15
# 15.0
# K2 La2 O10 Ti3
# 10.0
# O7 Sr3 Ti2
# 7.0
# O10 Sr4 Ti3
# 10.0
# La2 O7 Ti2
# 7.0
# Ca La4 O17 Ti5
# 17.0
# Ba La4 O15 Ti4
# 15.0
# Ca2 Nb2 O7
# 7.0
# Nb2 O7 Sr2
# 7.0
# Ba5 Nb4 O15
# 15.0
# Bi2 O9 Sr Ta2
# 9.0
# Fe O6 Sn Sr2
# 6.0
# K2 La2 O10 Ti3
# 10.0
# H0.9 K0.2 La2 O10 Sn0.45 Ti3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# Bi2 O10 Ti3
# 10.0
# Bi2 O10 Ti3
# 10.0
# O7 Sr2 Ta2
# 7.0
# Nb2 O7 Sr2
# 7.0
# Ni O
# 1.0
# O17 Rb4 Ta6
# 17.0
# Nb6 O17 Rb4
# 17.0
# O4 Sr2 Ti
# 4.0
# La0.1 O4 Sr1.9 Ti
# 4.0
# La0.2 O4 Sr1.8 Ti
# 4.0
# La0.3 O4 Sr1.7 Ti
# 4.0
# La0.4 O4 Sr1.6 Ti
# 4.0
# La0.5 O4 Sr1.5 Ti
# 4.0
# Ca2 Cs O10 Ta3
# 10.0
# Ca1.97 Cs0.03 Na0.91 O10 Ta3
# 10.0
# H0.87 Ca2.11 Cs0.03 Na0.1 O10 Ta3
# 10.0
# H Ca2 O10 Ta3
# 10.0
# Bi5 Fe O15 Ti3
# 15.0
# Bi4 Fe La O15 Ti3
# 15.0
# Bi3 Fe La2 O15 Ti3
# 15.0
# Bi2 O6 W
# 6.0
# K La O4 Ti
# 4.0
# K La O4 Ti0.9 Zr0.1
# 4.0
# K La O4 Ti0.7 Zr0.3
# 4.0
# K La O4 Ti0.5 Zr0.5
# 4.0
# K La O4 Ti0.3 Zr0.7
# 4.0
# K La O4 Zr
# 4.0
# K2 La2 O10 Ti3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# Fe0.1 K2 La2 O10 Ti2.9
# 10.0
# Fe0.2 K2 La2 O10 Ti2.8
# 10.0
# Fe0.3 K2 La2 O10 Ti2.7
# 10.0
# Fe0.4 K2 La2 O10 Ti2.6
# 10.0
# Fe0.5 K2 La2 O10 Ti2.5
# 10.0
# K2 La2 O10 Ti2.8 W0.2
# 10.0
# K2 La2 Ni0.2 O10 Ti2.8
# 10.0
# H2 O7 Sr Ta2
# 7.0
# Li2 O7 Sr Ta2
# 7.0
# K2 O7 Sr Ta2
# 7.0
# O7 Rb2 Sr Ta2
# 7.0
# K O3 Ta
# 3.0
# K6 La2 O21 Ta6
# 21.0
# H6 La2 O21 Ta6
# 21.0
# La O9 Ta3
# 9.0
# H2 O7 Sr Ta2
# 7.0
# K2 O10 Sr1.5 Ta3
# 10.0
# O7 Sr3 Ti2
# 7.0
# Ca2 Na2 Nb4 O13
# 13.0
# Fe O6 Sr2 Ta
# 6.0
# Fe O7 Sr3 Ta
# 7.0
# Fe O8 Sr4 Ta
# 8.0
# K2.33 Nb5 O14.335 Sr0.67
# 14.335
# H2.33 Nb5 O14.335 Sr0.67
# 14.335
# H2.33 Nb5 O14.335 Sr0.67
# 14.335
# Bi2 O9 W2
# 9.0
# Bi2 O6 W
# 6.0
# Bi14 O27 W2
# 27.0
# Bi2 O7 Ti2
# 7.0
# Bi4 O12 Ti3
# 12.0
# Bi3 Nb O9 Ti
# 9.0
# Bi2 Mo O6
# 6.0
# Ba Bi4 O15 Ti4
# 15.0
# Bi2 Mo O6
# 6.0
# Bi2 Nb2 O9 Pb
# 9.0
# O2 Ti
# 2.0
# Bi2 Ca Nb2 O9
# 9.0
# Bi2 Nb2 O9 Sr
# 9.0
# Ba Bi2 Nb2 O9
# 9.0
# Bi2 Ca O9 Ta2
# 9.0
# Bi2 O9 Sr Ta2
# 9.0
# Ba Bi2 O9 Ta2
# 9.0
# Bi2 K0.5 La0.5 O9 Ta2
# 9.0
# Bi2 K0.5 La0.5 Nb2 O9
# 9.0
# H1.9 Bi0.1 K0.3 La0.5 O7 Ta2
# 7.0
# H1.6 Bi0.1 K0.2 La0.3 Nb2 O6.5
# 6.5
# K2 La O15 Ta5
# 15.0
# Bi0.2 Ca0.8 H1.8 O7 Ta2
# 7.0
# Bi0.2 H1.8 O7 Sr Ta2
# 7.0
# Ba0.8 Bi0.1 H1.9 O7 Ta2
# 7.0
# Bi0.1 H1.9 K0.3 La0.5 O7 Ta2
# 7.0
# Bi4 Cl Nb8 O
# 1.0
# Bi Cl O
# 1.0
# Bi4 Cl Nb O8
# 8.0
# Bi4 Br Nb O8
# 8.0
# Bi4 Cl O8 Ta
# 8.0
# Bi4 Br O8 Ta
# 8.0
# H La O7 Ta2
# 7.0
# La Na O7 Ta2
# 7.0
# La O7 Rb Ta2
# 7.0
# Cs La O7 Ta2
# 7.0
# H O7 Pr Ta2
# 7.0
# Na O7 Pr Ta2
# 7.0
# O7 Pr Rb Ta2
# 7.0
# Cs O7 Pr Ta2
# 7.0
# H Nd O7 Ta2
# 7.0
# Na Nd O7 Ta2
# 7.0
# Nd O7 Rb Ta2
# 7.0
# Cs Nd O7 Ta2
# 7.0
# H O7 Sm Ta2
# 7.0
# Na O7 Sm Ta2
# 7.0
# O7 Rb Sm Ta2
# 7.0
# Cs O7 Sm Ta2
# 7.0
# Ca2 Li O10 Ta3
# 10.0
# Ca2 H Nb3 O10
# 10.0
# Ca2 H Nb3 O10
# 10.0
# H Nb3 O10 Sr2
# 10.0
# H La Nb2 O7
# 7.0
# K Nb3 O10 Sr2
# 10.0
# K Nb2 O10 Sr2 Ta
# 10.0
# K Nb O10 Sr2 Ta
# 10.0
# K Nb O10 Sr2 Ta2
# 10.0
# K O10 Sr2 Ta3
# 10.0
# H Nb3 O10 Sr2
# 10.0
# H Nb2 O10 Sr2 Ta
# 10.0
# H Nb O10 Sr2 Ta
# 10.0
# H Nb O10 Sr2 Ta2
# 10.0
# H O10 Sr2 Ta3
# 10.0
# H Nb3 O10 Sr2
# 10.0
# H Nb2 O10 Sr2 Ta
# 10.0
# H Nb O10 Sr2 Ta
# 10.0
# H Nb O10 Sr2 Ta2
# 10.0
# H O10 Sr2 Ta3
# 10.0
# Ca2 K Nb3 O10
# 10.0
# La Na Nb2 Ni O9 Sr
# 9.0
# Cs La Nb2 Ni O9 Sr
# 9.0
# H La Nb2 Ni O9 Sr
# 9.0
# Ca2 H1 Nb3 O10
# 10.0
# Ca2 H1 Nb2 O10 Ta1
# 10.0
# Ca2 H1 Nb1.5 O10 Ta1.5
# 10.0
# Ca2 H1 Nb1 O10 Ta2
# 10.0
# Ca2 H1 O10 Ta3
# 10.0
# La Nb2 O7 Rb
# 7.0
# Ag La Nb2 O7
# 7.0
# La Nb2 O7 Rb
# 7.0
# Ag La Nb2 O7
# 7.0
# Ca2 Nb3 O10 Rb
# 10.0
# Ag Ca2 Nb3 O10
# 10.0
# Nb3 O10 Rb Sr2
# 10.0
# Ag Nb3 O10 Sr2
# 10.0
# La2 O10 Rb2 Ti3
# 10.0
# Ag2 La2 O10 Ti3
# 10.0
# Ag La Nb2 O7
# 7.0
# Ag Ca2 Nb3 O10
# 10.0
# Ag Nb3 O10 Sr2
# 10.0
# Ag2 La2 O10 Ti3
# 10.0
# Ba5 Nb4 O15
# 15.0
# Ca2 Nb2 O7
# 7.0
# Nb2 O7 Sr2
# 7.0
# La2 O7 Ti2
# 7.0
# Ca La4 O17 Ti5
# 17.0
# O2 Ti
# 2.0
# K4 Nb6 O17
# 17.0
# Ba2 K O10 Ta3
# 10.0
# O7 Sr2 Ta2
# 7.0
# Nb0.1 O7 Sr2 Ta1.9
# 7.0
# Nb0.2 O7 Sr2 Ta1.8
# 7.0
# Nb0.3 O7 Sr2 Ta1.7
# 7.0
# Nb0.5 O7 Sr2 Ta1.5
# 7.0
# Nb0.7 O7 Sr2 Ta1.3
# 7.0
# Nb1 O7 Sr2 Ta1
# 7.0
# Nb1.6 O7 Sr2 Ta0.4
# 7.0
# Nb2 O7 Sr2
# 7.0
# La2 O7 Ti2
# 7.0
# La Nd O7 Ti2
# 7.0
# Nd2 O7 Ti2
# 7.0
# O7 Pr2 Ti2
# 7.0
# La O7 Pr Ti2
# 7.0
# K2 La2 O10 Ti3
# 10.0
# Cu2 La2 O10 Ti3
# 10.0
# Cu2.76 K1.24 Nb6 O17
# 17.0
# K4 Nb6 O17
# 17.0
# Cu0.65 K0.35 La Nb2 O7
# 7.0
# K La Nb2 O7
# 7.0
# Ca2 Cu0.1 O10 Rb0.9 Ta3
# 10.0
# Ca2 O10 Rb Ta3
# 10.0
# Li O3 Ta
# 3.0
# Na O3 Ta
# 3.0
# Cu0.02 Li0.98 O3 Ta
# 3.0
# Cu0.09 Na0.91 O3 Ta
# 3.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# O2 Ti
# 2.0
# H La Nb2 O7
# 7.0
# H0.98 La Mo0.02 Nb1.98 O7
# 7.0
# H0.95 La Mo0.05 Nb1.95 O7
# 7.0
# H0.85 La Mo0.15 Nb1.85 O7
# 7.0
# H La Nb2 O7
# 7.0
# H0.98 La Mo0.02 Nb1.98 O7
# 7.0
# H0.95 La Mo0.05 Nb1.95 O7
# 7.0
# H0.85 La Mo0.15 Nb1.85 O7
# 7.0
# Bi2 Nb1.8 O9 Pb W0.2
# 9.0
# Bi2 Nb1.85 O9 Pb W0.15
# 9.0
# Bi2 Nb1.9 O9 Pb W0.1
# 9.0
# Bi2 Nb2 O9 Pb
# 9.0
# Bi2 Nb1.9 O9 Pb Ti0.1
# 9.0
# Bi4 O12 Ti3
# 12.0
# Ca2 Cs O10 Ta3
# 10.0
# Ca2 Cs O10 Ta3
# 10.0
# H Nb3 O10 Pb2
# 10.0
# H1.8 Cr0.4 Nb2.6 O10 Pb2
# 10.0
# Ba5 O15 Ta4
# 15.0
# Ba5 O15 Ta4
# 15.0
# O15 Sr5 Ta4
# 15.0
# O15 Sr5 Ta4
# 15.0
# O7 Sr2 Ta2
# 7.0
# O7 Sr2 Ta2
# 7.0
# La2 O7 Ti2
# 7.0
# La2 O7 Ti2
# 7.0
# Fe0.02 La1.98 O7 Ti2
# 7.0
# Cr0.02 La1.98 O7 Ti2
# 7.0
# Nb2 O7 Sr2
# 7.0
# La2 O7 Ti2
# 7.0
# La2 O7 Ti2
# 7.0
# K2 La2 O10 Ti3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# O2 Ti
# 2.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# H La Nb2 O7
# 7.0
# Ca2 H Nb3 O10
# 10.0
# Ca2 H Nb2 O10 Ta
# 10.0
# Ca2 H Nb3 O10
# 10.0
# Ca2 H Nb2 O10 Ta
# 10.0
# La2 O7 Ti2
# 7.0
# Bi2 Ca Nb2 O9
# 9.0
# Bi2 Nb2 O9 Sr
# 9.0
# Ba Bi2 Nb2 O9
# 9.0
# Bi2 Ca Nb2 O9
# 9.0
# Bi2 Nb2 O9 Sr
# 9.0
# Ba Bi2 Nb2 O9
# 9.0
# Na2 O6 Ta2
# 6.0
# K2 O6 Ta2
# 6.0
# Ca2 O7 Ta2
# 7.0
# Ca2 Nb2 O7
# 7.0
# La2 O7 Ti2
# 7.0
# Ba5 O15 Ta4
# 15.0
# Ba5 Nb2 O15 Ta2
# 15.0
# Ba5 Nb4 O15
# 15.0
# O Zn
# 1.0
# O Zn
# 1.0
# O Zn
# 1.0
# Cd S
# 0
# Cd0.9 Zn0.1
# 0
# Cd0.7 Zn0.3
# 0
# Cd0.5 Zn0.5
# 0
# Cd0.3 Zn0.7
# 0
# Cd0.1 Zn0.9
# 0
# S Zn
# 0
# O6 Sr Ta2
# 6.0
# O9 Sr4 Ta2
# 9.0
# O15 Sr5 Ta4
# 15.0
# Bi2 Cu O4
# 4.0
# K4 Nb6 O17
# 17.0
# Ca2 Cs O10 Ta3
# 10.0
# Ca2 Cs O10 Ta3
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ba5 Nb4 O15
# 15.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ba0.5 Cs O10 Sr1.5 Ta3
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ba2 Cs Nb3 O10
# 10.0
# Ba2 H Nb3 O10
# 10.0
# H Nb3 O19 Sr2
# 19.0
# C H6 N Nb3 O19 Sr2
# 19.0
# C2 H8 N Nb3 O19 Sr2
# 19.0
# C3 H10 N Nb3 O19 Sr2
# 19.0
# C4 H12 N Nb3 O19 Sr2
# 19.0
# C6 H16 N Nb3 O19 Sr2
# 19.0
# C8 H20 N Nb3 O19 Sr2
# 19.0
# C H5 N Nb3 O20 Sr2
# 20.0
# C2 H7 N Nb3 O20 Sr2
# 20.0
# C3 H9 N Nb3 O20 Sr2
# 20.0
# C4 H11 N Nb3 O20 Sr2
# 20.0
# C6 H15 N Nb3 O20 Sr2
# 20.0
# C8 H19 N Nb3 O20 Sr2
# 20.0
# La2 Li2 O10 Ti3
# 10.0
# La2 Na2 O10 Ti3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# Li2 Nd2 O10 Ti3
# 10.0
# Na2 Nd2 O10 Ti3
# 10.0
# K2 Nd2 O10 Ti3
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 K Nb3 O10
# 10.0
# La O7 Rb Ta2
# 7.0
# La O7 Rb Ta2
# 7.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 K Na Nb4 O13
# 13.0
# Ca2 K Na2 Nb5 O16
# 16.0
# Ca2 K Na3 Nb6 O19
# 19.0
# Ca2 H Nb3 O10
# 10.0
# Ca1.5 H Nb3 O10 Sr0.5
# 10.0
# Ca H Nb3 O10 Sr
# 10.0
# Ca0.5 H Nb3 O10 Sr1.5
# 10.0
# H Nb3 O10 Sr2
# 10.0
# Ca2 H Nb2.7 O10 Ta0.3
# 10.0
# Ca2 H Nb2 O10 Ta
# 10.0
# Ca2 H Nb1.5 O10 Ta1.5
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ca K Nb3 O10 Sr
# 10.0
# K Nb3 O10 Sr2
# 10.0
# Ca2 H Nb3 O10
# 10.0
# H4 Nb6 O17
# 17.0
# Ca2 H Nb2.7 O10 Ta0.3
# 10.0
# Ca2 H Nb1.5 O10 Ta1.5
# 10.0
# La2 O7 Ti2
# 7.0
# La2 O7 Ti2
# 7.0
# Ca2 K O10 Ta3
# 10.0
# Ca2 H Nb3 O10
# 10.0
# Ca2 H Nb3 O10
# 10.0
# Ba2 Cs O10 Ta3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# K2 La2 O10 Ti3
# 10.0
# Bi2 O6 W
# 6.0
# Cs0.67 O4 Ti1.83
# 4.0
# H La O4 Ti
# 4.0
# H6 C La N O4 Ti
# 4.0
# H8 C2 La N O4 Ti
# 4.0
# H10 C3 La N O4 Ti
# 4.0
# H12 C4 La N O4 Ti
# 4.0
# H16 C6 La N O4 Ti
# 4.0
# H20 C8 La N O4 Ti
# 4.0
# H5 C La O5 Ti
# 5.0
# H7 C2 La O5 Ti
# 5.0
# H9 C3 La O5 Ti
# 5.0
# H11 C4 La O5 Ti
# 5.0
# H15 C6 La O5 Ti
# 5.0
# H19 C8 La O5 Ti
# 5.0
# H Nd O4 Ti
# 4.0
# H6 C Nd N O4 Ti
# 4.0
# H8 C2 Nd N O4 Ti
# 4.0
# H10 C3 Nd N O4 Ti
# 4.0
# H12 C4 Nd N O4 Ti
# 4.0
# H16 C6 Nd N O4 Ti
# 4.0
# H20 C8 Nd N O4 Ti
# 4.0
# H5 C Nd O5 Ti
# 5.0
# H7 C2 Nd O5 Ti
# 5.0
# H9 C3 Nd O5 Ti
# 5.0
# H11 C4 Nd O5 Ti
# 5.0
# H15 C6 Nd O5 Ti
# 5.0
# H19 C8 Nd O5 Ti
# 5.0
# H Nb3 O10 Sr2
# 10.0
# Ca2 H Nb3 O10
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 H Nb3 O10
# 10.0
# C Ca2 H5 Nb3 O10
# 10.0
# C2 Ca2 H7 Nb3 O10
# 10.0
# C3 Ca2 H9 Nb3 O10
# 10.0
# C4 Ca2 H11 Nb3 O10
# 10.0
# C6 Ca2 H15 Nb3 O10
# 10.0
# C8 Ca2 H19 Nb3 O10
# 10.0
# La2 O10 Rb2 Ti3
# 10.0
# H La2 O10 Rb Ti3
# 10.0
# H1.5 La2 O10 Rb0.5 Ti3
# 10.0
# H2 La2 O10 Ti3
# 10.0
# H Nd O7 Ta2
# 7.0
# Li Nd O7 Ta2
# 7.0
# Na Nd O7 Ta2
# 7.0
# K Nd O7 Ta2
# 7.0
# Nd O7 Rb Ta2
# 7.0
# Cs Nd O7 Ta2
# 7.0
# Ca2 H Nb3 O10
# 10.0
# C4 H12 Ca2 N Nb3 O10
# 10.0
# C2 H7 Ca2 Nb3 O11
# 11.0
# H La2 O10 Ti3
# 10.0
# C2 H8 La2 N O10 Ti3
# 10.0
# C2 H7 La2 O11 Ti3
# 11.0
# Ca2 H Nb3 O10
# 10.0
# C Ca2 H6 Nb3 O10
# 10.0
# C2 Ca2 H8 Nb3 O10
# 10.0
# C3 Ca2 H10 Nb3 O10
# 10.0
# C4 Ca2 H12 Nb3 O10
# 10.0
# C6 Ca2 H16 Nb3 O10
# 10.0
# C8 Ca2 H20 Nb3 O10
# 10.0
# H2 La2 O10 Ti3
# 10.0
# C H6 La2 N O10 Ti3
# 10.0
# C2 H8 La2 N O10 Ti3
# 10.0
# C3 H10 La2 N O10 Ti3
# 10.0
# C4 H12 La2 N O10 Ti3
# 10.0
# C6 H16 La2 N O10 Ti3
# 10.0
# C8 H20 La2 N O10 Ti3
# 10.0
# C H5 La2 O11 Ti3
# 11.0
# C2 H7 La2 O11 Ti3
# 11.0
# C3 H9 La2 O11 Ti3
# 11.0
# C4 H11 La2 O11 Ti3
# 11.0
# C6 H15 La2 O11 Ti3
# 11.0
# C8 H19 La2 O11Ti3
# 11.0
# H2 Nd2 O10 Ti3
# 10.0
# C H7 Nd2 O10 Ti3
# 10.0
# C2 H9 Nd2 O10 Ti3
# 10.0
# C3 H11 Nd2 O10 Ti3
# 10.0
# C4 H13 Nd2 O10 Ti3
# 10.0
# C6 H17 Nd2 O10 Ti3
# 10.0
# C8 H21 Nd2 O10 Ti3
# 10.0
# C H6 Nd2 O11 Ti3
# 11.0
# C2 H8 Nd2 O11 Ti3
# 11.0
# C3 H10 Nd2 O11 Ti3
# 11.0
# C4 H12 Nd2 O11 Ti3
# 11.0
# C6 H16 Nd2 O11 Ti3
# 11.0
# C8 H20 Nd2 O11 Ti3
# 11.0
# Bi2 H4 K O13 Ti4
# 13.0
# C Bi2 H7 K0.5 O13 Ti4
# 13.0
# C2 Bi2.5 H9 K0.5 O13 Ti4
# 13.0
# C3 Bi2.5 H11 K0.5 O13 Ti4
# 13.0
# C4 Bi2.5 H13 K0.5 O13 Ti4
# 13.0
# C6 Bi2.5 H17 K0.5 O13 Ti4
# 13.0
# C8 Bi2.5 H21 K0.5 O13 Ti4
# 13.0
# H2 Nd2 O10 Ti3
# 10.0
# C4 H13 N Nd2 O10 Ti3
# 10.0
# Bi2 O9 Sr Ta2
# 9.0
# Eu0.6 Gd1.4 K2 O10 Ti3
# 10.0
# Eu0.6 Gd1.4 H2 O10 Ti3
# 10.0
# La0.7 O7 Rb Ta2 Tb0.3
# 7.0
# La0.7 O7 Ta2 Tb0.3
# 7.0
# La3 Ni2 O6.92
# 6.92
# La3 Ni2 O6.35
# 6.35
# La0.33 Nb O3
# 3.0
# La0.33 O3 Ta
# 3.0
# Ca O3 Ti
# 3.0
# Bi3 Cl O11 Sr2 Ta2
# 11.0
# Bi3 Cl O11 Pb Sr Ta2
# 11.0
# Ba2 Bi3 Cl O11 Ta2
# 11.0
# Ba Bi3 Cl O11 Pb Ta2
# 11.0
# Bi4 Cl O11 Sr Ta Ti
# 11.0
# Ba Bi4 Cl O11 Ta Ti
# 11.0
# Bi4 Cl O11 Pb Ta Ti
# 11.0
# Bi3 Cl Nb2 O11 Sr2
# 11.0
# Bi3 Cl Nb2 O11 Pb Sr
# 11.0
# Ba2 Bi3 Cl Nb2 O11
# 11.0
# Ba Bi3 Cl Nb2 O11 Pb
# 11.0
# Bi4 Cl Nb O11 Sr Ti
# 11.0
# Ba Bi4 Cl Nb O11 Ti
# 11.0
# Bi4 Cl Nb O11 Pb Ti
# 11.0
# Ca2 H Nb3 O10
# 10.0
# Ca2 H Nb3 O10
# 10.0
# C Ca2 H6 N Nb3 O10
# 10.0
# C4 Ca2 H12 N Nb3 O10
# 10.0
# C8 Ca2 H20 N Nb3 O10
# 10.0
# C Ca2 H6 N Nb3 O10
# 10.0
# C4 Ca2 H12 N Nb3 O10
# 10.0
# C8 Ca2 H20 N Nb3 O10
# 10.0
# C Ca2 H6 N Nb3 O10
# 10.0
# C4 Ca2 H12 N Nb3 O10
# 10.0
# C8 Ca2 H20 N Nb3 O10
# 10.0
# Ca2 K Nb3 O10
# 10.0
# Ca2 K Nb2 O10 Ta
# 10.0
# Ca2 K Nb O10 Ta2
# 10.0
# Ca2 K O10 Ta3
# 10.0
# Ca2 K O10 Ta3
# 10.0

# %%
df['Oxygen_concentration']=df['Z']*df['Oxygen_count']/df['Volume']
df['Oxygen_concentration_MP']=df['Z_MP']*df['Oxygen_count']/df['Volume_MP']
df['Oxygen_concentration_COD']=df['Z_COD']*df['Oxygen_count']/df['Volume_COD']
df['Oxygen_concentration_Springer']=df['Z_Springer']*df['Oxygen_count']/df['Volume_Springer']

# %%
df.to_excel('oxygen concentration.xlsx')
