# %%
import pandas as pd

# %%
df = pd.read_csv(f"Data/Mattergen_dataset/processed/train.csv")

# %%
df
# Out:
#       Unnamed: 0 material_id  formation_energy_per_atom  dft_band_gap  \
# 0              0  mp-1221227                  -1.637460        0.2133
# 1              1   mp-561310                  -2.160561        4.3134
# 2              2   mp-755297                  -1.742646        2.5515
# 3              3   mp-547792                  -2.053321        2.6838
# 4              4   mp-684705                  -2.826178        1.3135
# ...          ...         ...                        ...           ...
# 4679        4679  mp-1174519                  -2.138699        0.0046
# 4680        4680    mp-10429                  -3.883507        4.3316
# 4681        4681  mp-1218572                  -3.619344        2.6040
# 4682        4682  mp-1213022                  -2.596619        0.9962
# 4683        4683   mp-756354                  -3.712252        2.7684
#
#      pretty_formula  e_above_hull                       elements  \
# ...

# %%
import plotly.express as px
import numpy as np

# %%
# Create the histogram
fig = px.histogram(
    df, 
    x="Log_rate", 
    nbins=30, 
    title="Value Distribution"
)

# Display the plot
fig.show()
